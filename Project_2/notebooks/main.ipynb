# %%
import sys

print(sys.executable)
# Out:
# c:\Users\Marian\Downloads\Projects\Portfolio\Project_2\.venv\Scripts\python.exe

# %%
import cv2
import numpy as np
import pandas as pd
from PIL import Image

# %%
from sentence_transformers import SentenceTransformer

# %%
import  faiss
